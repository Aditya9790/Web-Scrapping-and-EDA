# %% [markdown]
# # Pandas Profiling
# Pandas profiling is a module which helps us to get insites from the data and generats report which summirises all the data along with basic statistical analysis like variance, standard deviation, outlier analysis, etc.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# %%
from pandas_profiling import ProfileReport
import pandas as pd
import numpy as np
from google.colab import files

# %%
url='https://drive.google.com/file/d/1KjrSid8AfVggkCX3pmcpRE-OAi8CHVUr/view?usp=sharing'
url2='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url2, encoding='latin-1')
df.head()
# Out:
#      City[a]  ... Urban area[12] Density (/km2)
# 0      Tokyo  ...                        4751.0
# 1      Delhi  ...                       14272.0
# 2      Seoul  ...                        8087.0
# 3   Shanghai  ...                        5436.0
# 4  São Paulo  ...                        6949.0
#
# [5 rows x 13 columns]

# %% [markdown]
# Pandas Profiling generates a report and gives insites on the data

# %%
prof = ProfileReport(df)
prof.to_file('report.html')
files.download('report.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
